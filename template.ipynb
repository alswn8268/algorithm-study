# %% [markdown]
# # [플랫폼] 문제번호. 문제이름
#
# - **링크**: [문제 링크](URL)
# - **난이도**:
# - **태그**: `#태그1` `#태그2`
# - **풀이일**: YYYY-MM-DD

# %% [markdown]
# ## 문제 요약
#
# > 문제 핵심 내용을 간단히 정리

# %% [markdown]
# ## 접근 방식
#
# - 아이디어 설명
# - 알고리즘 선택 이유

# %%
# 풀이 코드

# %% [markdown]
# ## 복잡도 분석
#
# - **시간 복잡도**: O( )
# - **공간 복잡도**: O( )

# %% [markdown]
# ## 회고
#
# - 어려웠던 점:
# - 개선 사항 / 다른 풀이:
